# %%
# %matplotlib inline

# %% [markdown]
# # エクセルファイルの読み込み

# %%
import pandas as pd

this_file_name = "met_tokyo.xlsx"   # 読み込みファイル名
this_sh_name = "tokyo_2017"    # 読み込みシート名
this_skiprows = 6                # 最初に読み飛ばす行数
this_usecols = [0,1,4,7,10,15] # dataframe化する列を0始まりのインデックスで指定
this_col_names = ["年月日","平均気温(℃)","最高気温(℃)","最低気温(℃)",
							"降水量(mm)","平均湿度(%)"]  # 使用する列の名前を付ける


xlsx_pd = pd.read_excel(this_file_name, sheetname = this_sh_name,
													names = this_col_names, usecols = this_usecols,
													skiprows = this_skiprows)

xlsx_pd
# Out:
# c:\python\python37\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#            年月日  平均気温(℃)  最高気温(℃)  最低気温(℃)  降水量(mm)  平均湿度(%)
# 0   2017-01-02      7.2     13.3      3.8      0.0        8
# 1   2017-01-03      8.0     13.7      3.5      0.0        8
# 2   2017-01-04      8.5     14.0      3.6      0.0        8
# 3   2017-01-05      6.7     10.4      3.7      0.0        8
# 4   2017-01-06      4.5      8.8      1.5      0.0        8
# 5   2017-01-07      4.1      8.7      0.1      0.0        8
# 6   2017-01-08      3.9      6.0      1.6     20.5        8
# 7   2017-01-09      7.2     11.1      3.8      5.5        8
# 8   2017-01-10      8.1     12.7      3.5      0.0        8
# 9   2017-01-11      6.9     11.0      3.9      0.0        8
# 10  2017-01-12      6.0     12.1      0.7      0.0        8
# 11  2017-01-13      6.2     12.7      1.4      0.0        8
# 12  2017-01-14      2.4      6.3     -1.3      0.0        8
# 13  2017-01-15      0.7      4.7     -2.3      0.0        8
# 14  2017-01-16      3.2      8.0     -2.0      0.0        8
# 15  2017-01-17      5.4     10.9      0.7      0.0        8
# 16  2017-01-18      5.8     10.3      1.1      0.0        8
# 17  2017-01-19      6.4     10.9      2.4      0.0        8
# 18  2017-01-20      3.0      3.8      2.2      0.0        8
# 19  2017-01-21      5.9     11.0      1.2      0.0        8
# 20  2017-01-22      6.0     12.9      0.9      0.0        8
# 21  2017-01-23      4.0      7.9      0.2      0.0        8
# 22  2017-01-24      2.5      7.7     -1.9      0.0        8
# 23  2017-01-25      3.9      9.5     -1.2      0.0        8
# 24  2017-01-26      4.6     10.7     -1.4      0.0        8
# 25  2017-01-27      8.8     16.0      1.4      0.0        8
# 26  2017-01-28      8.4     13.6      4.6      0.0        8
# 27  2017-01-29      8.0     12.0      4.8      0.0        8
# 28  2017-01-30     11.2     19.5      6.7      0.0        8
# 29  2017-01-31      5.9     10.0      2.8      0.0        8
# ..         ...      ...      ...      ...      ...      ...
# 335 2017-12-03      8.2     12.5      5.2      0.0        8
# 336 2017-12-04      8.8     12.6      4.6      0.0        8
# 337 2017-12-05      9.2     14.5      4.4      0.0        8
# 338 2017-12-06      6.9     11.1      2.8      0.0        8
# 339 2017-12-07      6.4     11.5      2.7      0.0        8
# 340 2017-12-08      5.7      9.5      2.6      4.5        8
# 341 2017-12-09      5.9     10.4      1.2      0.0        8
# 342 2017-12-10      6.9     13.3      1.3      0.0        8
# 343 2017-12-11      9.9     16.0      5.1      0.0        8
# 344 2017-12-12      6.8     10.3      3.8      0.0        8
# 345 2017-12-13      5.9     10.4      2.6      0.0        8
# 346 2017-12-14      5.7     10.1      1.6      0.0        8
# 347 2017-12-15      5.4      8.3      3.0      0.0        8
# 348 2017-12-16      7.7     13.3      2.1      0.0        8
# 349 2017-12-17      6.1      9.3      3.3      0.0        8
# 350 2017-12-18      4.4      9.5     -0.2      0.0        8
# 351 2017-12-19      6.5     12.8      0.3      0.0        8
# 352 2017-12-20      5.7      9.4      2.3      0.0        8
# 353 2017-12-21      5.3     10.4      0.7      0.0        8
# 354 2017-12-22      5.4     10.9      1.5      0.0        8
# 355 2017-12-23      7.1     13.4      1.0      0.0        8
# 356 2017-12-24      7.4     10.8      4.5      0.0        8
# 357 2017-12-25      9.4     15.0      5.4     10.5        8
# 358 2017-12-26      7.5     12.6      3.6      0.0        8
# 359 2017-12-27      4.5      9.2      1.0      0.0        8
# 360 2017-12-28      4.8      9.8      1.1      0.0        8
# 361 2017-12-29      6.1     10.5      2.3      0.0        8
# 362 2017-12-30      6.2     11.1      1.0      0.0        8
# 363 2017-12-31      3.8      5.4      2.2      0.0        8
# 364 2018-01-01      6.2     13.0      0.4      0.0        8
#
# [365 rows x 6 columns]

# %% [markdown]
# # matplotlibによる表示

# %%
import matplotlib.pyplot as plt

plt.plot(xlsx_pd["年月日"],xlsx_pd["平均気温(℃)"],label="average",color="k")

plt.plot(xlsx_pd["年月日"],xlsx_pd["最低気温(℃)"],label="min",color="b")

plt.plot(xlsx_pd["年月日"],xlsx_pd["最高気温(℃)"],label="max",color="r")

# 軸ラベルの設定
plt.xlabel("date")
plt.ylabel("temperature")

plt.grid() # 方眼線の追加
plt.legend() # 凡例の追加
